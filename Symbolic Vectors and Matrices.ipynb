# %%
import sympy as sym

# %%
x = sym.symbols('x')
a, b, c, d  = sym.symbols('a,b,c,d')

# %%
P = sym.Matrix([[1,2*x],[3*x**2,4*x**3]])
P
# Out:
# Matrix([
# [     1,    2*x],
# [3*x**2, 4*x**3]])

# %%
a,b,c,d = sym.symbols('a,b,c,d')
w,x,y,z = sym.symbols('w,x,y,z')
A = sym.Matrix([[a,b],[c,d]])
B = sym.Matrix([[w,x],[y,z]])
A - B
# Out:
# Matrix([
# [a - w, b - x],
# [c - y, d - z]])

# %%
A
# Out:
# Matrix([
# [a, b],
# [c, d]])

# %%
B
# Out:
# Matrix([
# [w, x],
# [y, z]])

# %%
A * B
# Out:
# Matrix([
# [a*w + b*y, a*x + b*z],
# [c*w + d*y, c*x + d*z]])

# %%
sym.det(A)
# Out:
# a*d - b*c

# %%
sym.trace(A)
# Out:
# a + d

# %%
P = sym.Matrix([[1,2*x],[3*x**2,4*x**3]])
print(P)
sym.diff(P,x)
# Out:
# Matrix([
# [  0,       2],
# [6*x, 12*x**2]])

# %%
sym.diff(P,x,3)
# Out:
# Matrix([
# [0,  0],
# [0, 24]])

# %%
sym.integrate(P,x)
# Out:
# Matrix([
# [   x, x**2],
# [x**3, x**4]])

# %%
sym.integrate(P,(x,0,1))
# Out:
# Matrix([
# [1, 1],
# [1, 1]])
